# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Pruebas_PCR_procesadas_de_COVID-19_en_Colombia__Departamental_.csv')

# %%
data.set_index('Fecha', inplace=True)

# %%
data_ips1 = data*0.2
data_ips2 = data*0.3
data_ips3 = data*0.5

# %%
data_ips1.to_csv('data_ips1.csv')
data_ips2.to_csv('data_ips2.csv')
data_ips3.to_csv('data_ips3.csv')

# %%
data_ips1 + data_ips2+ data_ips3 == data
# Out:
#                          Acumuladas  Amazonas  Antioquia  Arauca  Atlantico  \
# Fecha
# Acumulado Feb                  True     False      False   False      False
# 2020-03-05T00:00:00.000        True     False      False   False      False
# 2020-03-06T00:00:00.000        True     False      False   False      False
# 2020-03-07T00:00:00.000        True     False      False   False      False
# 2020-03-08T00:00:00.000        True     False      False   False      False
# ...                             ...       ...        ...     ...        ...
# 2021-09-30T00:00:00.000        True      True       True    True       True
# 2021-10-01T00:00:00.000        True      True       True    True       True
# 2021-10-02T00:00:00.000        True      True       True    True       True
# 2021-10-03T00:00:00.000        True      True       True    True       True
# 2021-10-04T00:00:00.000        True      True       True    True       True
#
# ...
